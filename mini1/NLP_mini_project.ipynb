# %%
# import os
# os.kill(os.getpid(), 9)

# %%
# Get data
with open('/content/drive/MyDrive/Colab Notebooks/NLP/data/NLP_Dataset2.txt', 'r') as f:
  text = f.read().replace('\n', '')

print(text)
# Out:
# The weather was cold and gray as usual at this time of year. The trees were all leafless, with fall now just a memory. Christmas was just a few weeks away, and all the kids were looking forward to staying home from school for a few weeks and to the “big payoff” on Christmas morning. Not having to go to school was good, but usually by the time vacation was over, going to school was a big relief. Back to the friends to compare “loot” from Christmas and, to reestablish those fragile ties that hold kids together. At school, students were praised for doing good work, not belittled for each and every mistake. No one there was fighting, and being too loud was against the rules. Right now, the world outside of home was more safe and structured, not chaotic, scary and loud. Even when bad things did happen, it was always far away and nothing to be too concerned about. With Dad often having too much to drink, and Mom just mad at everyone all the time, being home was not usually a very pleasant experience.Playing outside in the woods or at a friend’s house was the norm for three of us kids. We knew everyone that lived on our road, and except for the cranky old people who lived at the bottom of the hill, everyone was nice to us. In a small rural community, the only thing to be feared at that time of year was crashing on a sled or frost bite from staying out too long. Unless something like that happened, the only rule was to be home before dark.But that weekend morning was different. We were all home, and the day was starting off rather quietly. None of the kids were arguing, no dogs were barking, and Mom and Dad were actually talking, not shouting or sniping at each other. Dad was sitting at his spot at the dining room table, and Mom was in the kitchen starting breakfast. Usually sitting along the table with   Dad at the head was like being at a tennis match, watching the action and listening to the arguments between him at the end and Mom over at the stove.When the telephone rang, Dad didn’t pick it up, even though he was sitting next to it. Mom walked over behind him and answered the call.“Hello? Hi, Bobbie. What? What are you talking about? How did this happen? Oh, my God, I don’t believe it! When did they find her? Oh, poor Connie, how will she handle this?” Mom’s voice kept getting higher and higher in pitch, and the tears were starting to flow. This sort of response was totally out of character for her. We all just sat there trying to figure out what sort of gossip our next-door neighbor would have that would cause such a reaction. Dad didn’t say anything, but somehow knew that whatever had happened was completely out of the ordinary. Events occur during each lifetime that forever alter the perception of the world being a safe place to play in. Feeling secure means being at home, no matter the atmosphere, with the door locked up tight.When Mom finally got herself under control, she said in a low voice, “Margaret was found murdered this morning over on Lauffer Mine Road.” Suddenly, our safe little community became a place of uncertainty and confusion where one of the neighbor’s children was a victim of a killer. The thought that a murderer might be on the loose in our area was one without precedent. The most serious crimes until this moment had been kids corning and soaping the windows on Halloween night. The idea of something like this happening to one of the neighborhood children was almost unbelievable.As the day wore on, this tragedy lost some of its shock value and became a part of our reality. Mom was on the phone quite a bit, talking in hushed tones with the neighbors. The gossip mill was in full swing. Who did it? And why? Was it a stranger, or maybe someone we all knew?State police cars cruised up and down all day, looking everywhere, even around our house. All three of us stayed pretty close to home that day. No one was playing outside or calling us to come down the road to play. Dad was quite glad not to have to get on us t ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import io, sys, math, re
from collections import defaultdict
import numpy as np

# %%
# Tokenize sentences
from nltk.tokenize import sent_tokenize, word_tokenize

sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['The weather was cold and gray as usual at this time of year.', 'The trees were all leafless, with fall now just a memory.', 'Christmas was just a few weeks away, and all the kids were looking forward to staying home from school for a few weeks and to the “big payoff” on Christmas morning.', 'Not having to go to school was good, but usually by the time vacation was over, going to school was a big relief.', 'Back to the friends to compare “loot” from Christmas and, to reestablish those fragile ties that hold kids together.', 'At school, students were praised for doing good work, not belittled for each and every mistake.', 'No one there was fighting, and being too loud was against the rules.', 'Right now, the world outside of home was more safe and structured, not chaotic, scary and loud.', 'Even when bad things did happen, it was always far away and nothing to be too concerned about.', 'With Dad often having too much to drink, and Mom just mad at everyone all the time, being home was not usually a very pleasant experience.Playing outside in the woods or at a friend’s house was the norm for three of us kids.', 'We knew everyone that lived on our road, and except for the cranky old people who lived at the bottom of the hill, everyone was nice to us.', 'In a small rural community, the only thing to be feared at that time of year was crashing on a sled or frost bite from staying out too long.', 'Unless something like that happened, the only rule was to be home before dark.But that weekend morning was different.', 'We were all home, and the day was starting off rather quietly.', 'None of the kids were arguing, no dogs were barking, and Mom and Dad were actually talking, not shouting or sniping at each other.', 'Dad was sitting at his spot at the dining room table, and Mom was in the kitchen starting breakfast.', 'Usually sitting along the table with   Dad at the head was like being at a tennis match, watching the action and listening to the arguments between him at the end and Mom over at the stove.When the telephone rang, Dad didn’t pick it up, even though he was sitting next to it.', 'Mom walked over behind him and answered the call.“Hello?', 'Hi, Bobbie.', 'What?', 'What are you talking about?', 'How did this happen?', 'Oh, my God, I don’t believe it!', 'When did they find her?', 'Oh, poor Connie, how will she handle this?” Mom’s voice kept getting higher and higher in pitch, and the tears were starting to flow.', 'This sort of response was totally out of character for her.', 'We all just sat there trying to figure out what sort of gossip our next-door neighbor would have that would cause such a reaction.', 'Dad didn’t say anything, but somehow knew that whatever had happened was completely out of the ordinary.', 'Events occur during each lifetime that forever alter the perception of the world being a safe place to play in.', 'Feeling secure means being at home, no matter the atmosphere, with the door locked up tight.When Mom finally got herself under control, she said in a low voice, “Margaret was found murdered this morning over on Lauffer Mine Road.” Suddenly, our safe little community became a place of uncertainty and confusion where one of the neighbor’s children was a victim of a killer.', 'The thought that a murderer might be on the loose in our area was one without precedent.', 'The most serious crimes until this moment had been kids corning and soaping the windows on Halloween night.', 'The idea of something like this happening to one of the neighborhood children was almost unbelievable.As the day wore on, this tragedy lost some of its shock value and became a part of our reality.', 'Mom was on the phone quite a bit, talking in hushed tones with the neighbors.', 'The gossip mill was in full swing.', 'Who did it?', 'And why?', 'Was it a stranger, or maybe someone we all knew?State police cars cruised up and down all day, looking everywhere, even around our house.', 'All three of us stayed pretty close to home that day.', ...

# %%
# Process data
for i in range(len(sentences)):
  sentences[i] = sentences[i].replace(',',' ,')
  sentences[i] = sentences[i].replace('.',' .')
  sentences[i] = sentences[i].replace('“',' " ')
  sentences[i] = sentences[i].replace('”', ' " ')
  sentences[i] = sentences[i].lower()
  sentences[i] = '<s> ' + sentences[i] + ' </s>'

print(sentences)
# Out:
# ['<s> the weather was cold and gray as usual at this time of year . </s>', '<s> the trees were all leafless , with fall now just a memory . </s>', '<s> christmas was just a few weeks away , and all the kids were looking forward to staying home from school for a few weeks and to the  " big payoff "  on christmas morning . </s>', '<s> not having to go to school was good , but usually by the time vacation was over , going to school was a big relief . </s>', '<s> back to the friends to compare  " loot "  from christmas and , to reestablish those fragile ties that hold kids together . </s>', '<s> at school , students were praised for doing good work , not belittled for each and every mistake . </s>', '<s> no one there was fighting , and being too loud was against the rules . </s>', '<s> right now , the world outside of home was more safe and structured , not chaotic , scary and loud . </s>', '<s> even when bad things did happen , it was always far away and nothing to be too concerned about . </s>', '<s> with dad often having too much to drink , and mom just mad at everyone all the time , being home was not usually a very pleasant experience .playing outside in the woods or at a friend’s house was the norm for three of us kids . </s>', '<s> we knew everyone that lived on our road , and except for the cranky old people who lived at the bottom of the hill , everyone was nice to us . </s>', '<s> in a small rural community , the only thing to be feared at that time of year was crashing on a sled or frost bite from staying out too long . </s>', '<s> unless something like that happened , the only rule was to be home before dark .but that weekend morning was different . </s>', '<s> we were all home , and the day was starting off rather quietly . </s>', '<s> none of the kids were arguing , no dogs were barking , and mom and dad were actually talking , not shouting or sniping at each other . </s>', '<s> dad was sitting at his spot at the dining room table , and mom was in the kitchen starting breakfast . </s>', '<s> usually sitting along the table with   dad at the head was like being at a tennis match , watching the action and listening to the arguments between him at the end and mom over at the stove .when the telephone rang , dad didn’t pick it up , even though he was sitting next to it . </s>', '<s> mom walked over behind him and answered the call . " hello? </s>', '<s> hi , bobbie . </s>', '<s> what? </s>', '<s> what are you talking about? </s>', '<s> how did this happen? </s>', '<s> oh , my god , i don’t believe it! </s>', '<s> when did they find her? </s>', '<s> oh , poor connie , how will she handle this? "  mom’s voice kept getting higher and higher in pitch , and the tears were starting to flow . </s>', '<s> this sort of response was totally out of character for her . </s>', '<s> we all just sat there trying to figure out what sort of gossip our next-door neighbor would have that would cause such a reaction . </s>', '<s> dad didn’t say anything , but somehow knew that whatever had happened was completely out of the ordinary . </s>', '<s> events occur during each lifetime that forever alter the perception of the world being a safe place to play in . </s>', '<s> feeling secure means being at home , no matter the atmosphere , with the door locked up tight .when mom finally got herself under control , she said in a low voice ,  " margaret was found murdered this morning over on lauffer mine road . "  suddenly , our safe little community became a place of uncertainty and confusion where one of the neighbor’s children was a victim of a killer . </s>', '<s> the thought that a murderer might be on the loose in our area was one without precedent . </s>', '<s> the most serious crimes until this moment had been kids corning and soaping the windows on halloween night . </s>', '<s> the idea of something like this happening to one of the neighborhood children was almost unbelievable .as the day wore on , this tragedy lost some of its shock value ...

# %%
# Function to tokenize words in sentences
def tokenize_word(sentences):
  sentences_tokenized = []
  for sentence in sentences:
    words = sentence.split()
    sentences_tokenized.append(words)
  return sentences_tokenized

# %%
# Tokenize words in sentences
sentences = tokenize_word(sentences)

# %%
# Function to count the amount of word appeared
from collections import defaultdict
def get_count(sentences):
  vocab = defaultdict(lambda:0)

  for sentence in sentences:
    for word in sentence:
      vocab[word] += 1

  return vocab

# %%
# Count word
word_count = get_count(sentences)

# %%
word_count['.it']
# Out:
# 1

# %%
# Split data into 3
train_size = int(len(sentences)*0.7)
valid_size = int(len(sentences)*0.1)

train = sentences[:train_size]
valid = sentences[train_size:train_size+valid_size]
test = sentences[train_size+valid_size:]

print(len(train), len(valid), len(test))
# Out:
# 237 34 69

# %%
def build_ngram_backoff(data, n):
    '''
    Parameters:
    data (list of lists): each list is a sentence of the text
    n (int): size of the n-gram

    Returns:
    proba (dictionary of dictionary)
    {
        context: {word:probability of this word given context}
    }


    '''
    total_number_words = 0
    counts = defaultdict(lambda: defaultdict(lambda: 0.0))

    for sentence in data:
      sentence = tuple(sentence)
      ## FILL CODE
      # dict can be indexed by tuples
      # store in the same dict all the ngrams
      # by using the context as a key and the word as a value
      for i in range(len(sentence)):
        total_number_words +=1
        for k in range(n):
          if i-k < 0:
            break
          counts[sentence[i-k:i]][sentence[i]] +=1

    proba  = defaultdict(lambda: defaultdict(lambda: 0.0))
    # Build the probabilities from the counts
    # Be careful with how you normalize!

    for context in counts.keys():
    ## FILL CODE
      denom =0
      for w in counts[context].keys():
        denom += counts[context][w]
      for w in counts[context].keys():
        proba[context][w] = counts[context][w]/denom

    return proba

# %%
def build_ngram_interpolation(data, n, k, lambda_values):
    '''
    Parameters:
    data (list of lists): each list is a sentence of the text
    n (int): size of the n-gram
    k (float): smoothing parameter for add-k smoothing
    lambda_values (list): interpolation weights for different n-gram orders

    Returns:
    proba (dictionary of dictionary)
    {
        context: {word: probability of this word given context}
    }
    '''

    total_number_words = 0
    counts = defaultdict(lambda: defaultdict(lambda: 0.0))

    for sentence in data:
        sentence = tuple(sentence)
        for i in range(len(sentence)):
            total_number_words += 1
            for k in range(n):
                if i - k < 0:
                    break
                counts[sentence[i - k:i]][sentence[i]] += 1

    proba = defaultdict(lambda: defaultdict(lambda: 0.0))

    for context in counts.keys():
        denom = sum(counts[context].values()) + k * len(set([word for context in counts.keys() for word in context]))
        for w in counts[context].keys():
            proba[context][w] = (counts[context][w] + k) / denom

    # Interpolation
    for context in counts.keys():
        for i in range(1, n + 1):
            sub_context = context[-i:]
            lambda_i = lambda_values[i - 1]
            denom_i = sum(counts[sub_context].values()) + k * len(set([word for sub_context in counts.keys() for word in sub_context]))
            for w in counts[sub_context].keys():
                proba[context][w] += lambda_i * (counts[sub_context][w] + k) / denom_i

    return proba

# %%
n = 4
print("build ngram model with n = ", n)
model = build_ngram_backoff(train, n)
# Out:
# build ngram model with n =  4

# %%
n = 4
print("build ngram model with n = ", n)
model = build_ngram_interpolation(train, n, 0.2, [0.1, 0.2, 0.3, 0.4])
# Out:
# build ngram model with n =  4

# %%
def pretty_print_nested_dict(d, indent=0):
    for key, value in d.items():
        if isinstance(value, defaultdict):
            print("  " * indent + f"{key}:")
            pretty_print_nested_dict(value, indent + 1)
        else:
            print("  " * indent + f"{key}: {value}")

def print_all_key_value_pairs(d, indent=0, prefix=""):
    for key, value in d.items():
        if isinstance(value, defaultdict):
            print_all_key_value_pairs(value, indent + 1, prefix + f"{key}.")
        else:
            print("  " * indent + f"{prefix}{key}: {value}")

# %%
def get_prob(model, context, w):
    '''
    Parameters:
    model (dictionary of dictionary)
    {
        context: {word:probability of this word given context}
    }
    context (list of strings): a sentence
    w(string): the word we need to find it's probability given the context

    Retunrs:
    prob(float): probability of this word given the context
    '''

    # code a recursive function over
    # smaller and smaller context
    # to compute the backoff model

    ## FILL CODE

    if context in model and w in model[context]:
        return model[context][w]
    else:
        return 0.4*get_prob(model, context[1:], w)

# %%
def perplexity(model, data, n):
    '''
    Parameters:
    model (dictionary of dictionary)
    {
        context: {word:probability of this word given context}
    }
    data (list of lists): each list is a sentence of the text
    n(int): size of the n-gram

    Retunrs:
    prep(float): the preplexity of the model
    '''
    ## FILL CODE
    perp, T = 0.0, 0
    for sentence in data:
        sentence = tuple(sentence)
        for i in range(1, len(sentence)):
            nc = min(n-1, i)
            context = sentence[i-nc:i]
            perp += -math.log(get_prob(model, context, sentence[i]))
            T += 1
    perp = math.exp(perp/T)
    return perp

# %%
print("The perplexity is", perplexity(model, valid, n=2))
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-19-682391482b20> in <cell line: 1>()
# ----> 1 print("The perplexity is", perplexity(model, valid, n=2))
#
# <ipython-input-18-395e8b867d33> in perplexity(model, data, n)
#      19             nc = min(n-1, i)
#      20             context = sentence[i-nc:i]
# ---> 21             perp += -math.log(get_prob(model, context, sentence[i]))
#      22             T += 1
#      23     perp = math.exp(perp/T)
#
# <ipython-input-17-6a429b0faac1> in get_prob(model, context, w)
#      22         return model[context][w]
#      23     else:
# ---> 24         return 0.4*get_prob(model, context[1:], w)
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-17-6a429b0faac1> in get_prob(model, context, w)
#      22         return model[context][w]
#      23     else:
# ---> 24         return 0.4*get_prob(model, context[1:], w)
#
# RecursionError: maximum recursion depth exceeded

# %%
def get_proba_distrib(model, context):
    ## need to get the the words after the context and their probability of appearance
    ## after this context
    '''
    Parameters:
    model (dictionary of dictionary)
    {
        context: {word:probability of this word given context}
    }
    context (list of strings): the sentence we need to find the words after it and
    thier probabilites

    Retunrs:
    words_and_probs(dic): {word: probability of word given context}

    '''
    # code a recursive function over context
    # to find the longest available ngram

    ## FILL CODE

    if context in model:
        return model[context]
    else:
        return get_proba_distrib(model, context[1:])

# %%
def generate(model, context):
    '''
    Parameters:
    model (dictionary of dictionary)
    {
        context: {word:probability of this word given context}
    }

    Retunrs:
    sentence (list of strings): a sentence sampled according to the language model.


    '''
    # generate a sentence. A sentence starts with a <s> and ends with a </s>
    # Possiblly a use function is:
    # np.random.choice(x, 1, p = y)

    # where x is a list of things to sample from
    # and y is a list of probability (of the same length as x)
    sentence = ["<s>"]+context
    print(type(sentence))
    print(sentence)
    while sentence[-1] != "</s>" and len(sentence)<100:
        ## FILL CODE
        proba = get_proba_distrib(model, tuple(sentence))
        w = np.random.choice((list(proba.keys())), 1, p = list(proba.values()))
        sentence.append(w[0])

    result = ''
    for word in sentence:
        result = result + ' ' + word
    return result

# %%
print("Generated sentence: ",generate(model, ['i', 'was', 'just']))
# Out:
# <class 'list'>
# ['<s>', 'i', 'was', 'just']
# Generated sentence:   <s> i was just a few weeks and to the " big payoff " on christmas morning . </s>

# %%
sesss = ["<s>", "i"]
ppppp = get_proba_distrib(model, tuple(sesss))
ppppp.keys()
# Out:
# dict_keys(['was', 'can', 'look', 'swallow', 'had', 'feel', 'am', 'want'])

# %% [markdown]
# #Break

# %%
tokens = word_tokenize(' '.join(train))
print(tokens)
print(len(tokens))
# Out:
# ['The', 'weather', 'was', 'cold', 'and', 'gray', 'as', 'usual', 'at', 'this', 'time', 'of', 'year', '.', 'The', 'trees', 'were', 'all', 'leafless', ',', 'with', 'fall', 'now', 'just', 'a', 'memory', '.', 'Christmas', 'was', 'just', 'a', 'few', 'weeks', 'away', ',', 'and', 'all', 'the', 'kids', 'were', 'looking', 'forward', 'to', 'staying', 'home', 'from', 'school', 'for', 'a', 'few', 'weeks', 'and', 'to', 'the', '“', 'big', 'payoff', '”', 'on', 'Christmas', 'morning', '.', 'Not', 'having', 'to', 'go', 'to', 'school', 'was', 'good', ',', 'but', 'usually', 'by', 'the', 'time', 'vacation', 'was', 'over', ',', 'going', 'to', 'school', 'was', 'a', 'big', 'relief', '.', 'Back', 'to', 'the', 'friends', 'to', 'compare', '“', 'loot', '”', 'from', 'Christmas', 'and', ',', 'to', 'reestablish', 'those', 'fragile', 'ties', 'that', 'hold', 'kids', 'together', '.', 'At', 'school', ',', 'students', 'were', 'praised', 'for', 'doing', 'good', 'work', ',', 'not', 'belittled', 'for', 'each', 'and', 'every', 'mistake', '.', 'No', 'one', 'there', 'was', 'fighting', ',', 'and', 'being', 'too', 'loud', 'was', 'against', 'the', 'rules', '.', 'Right', 'now', ',', 'the', 'world', 'outside', 'of', 'home', 'was', 'more', 'safe', 'and', 'structured', ',', 'not', 'chaotic', ',', 'scary', 'and', 'loud', '.', 'Even', 'when', 'bad', 'things', 'did', 'happen', ',', 'it', 'was', 'always', 'far', 'away', 'and', 'nothing', 'to', 'be', 'too', 'concerned', 'about', '.', 'With', 'Dad', 'often', 'having', 'too', 'much', 'to', 'drink', ',', 'and', 'Mom', 'just', 'mad', 'at', 'everyone', 'all', 'the', 'time', ',', 'being', 'home', 'was', 'not', 'usually', 'a', 'very', 'pleasant', 'experience.Playing', 'outside', 'in', 'the', 'woods', 'or', 'at', 'a', 'friend', '’', 's', 'house', 'was', 'the', 'norm', 'for', 'three', 'of', 'us', 'kids', '.', 'We', 'knew', 'everyone', 'that', 'lived', 'on', 'our', 'road', ',', 'and', 'except', 'for', 'the', 'cranky', 'old', 'people', 'who', 'lived', 'at', 'the', 'bottom', 'of', 'the', 'hill', ',', 'everyone', 'was', 'nice', 'to', 'us', '.', 'In', 'a', 'small', 'rural', 'community', ',', 'the', 'only', 'thing', 'to', 'be', 'feared', 'at', 'that', 'time', 'of', 'year', 'was', 'crashing', 'on', 'a', 'sled', 'or', 'frost', 'bite', 'from', 'staying', 'out', 'too', 'long', '.', 'Unless', 'something', 'like', 'that', 'happened', ',', 'the', 'only', 'rule', 'was', 'to', 'be', 'home', 'before', 'dark.But', 'that', 'weekend', 'morning', 'was', 'different', '.', 'We', 'were', 'all', 'home', ',', 'and', 'the', 'day', 'was', 'starting', 'off', 'rather', 'quietly', '.', 'None', 'of', 'the', 'kids', 'were', 'arguing', ',', 'no', 'dogs', 'were', 'barking', ',', 'and', 'Mom', 'and', 'Dad', 'were', 'actually', 'talking', ',', 'not', 'shouting', 'or', 'sniping', 'at', 'each', 'other', '.', 'Dad', 'was', 'sitting', 'at', 'his', 'spot', 'at', 'the', 'dining', 'room', 'table', ',', 'and', 'Mom', 'was', 'in', 'the', 'kitchen', 'starting', 'breakfast', '.', 'Usually', 'sitting', 'along', 'the', 'table', 'with', 'Dad', 'at', 'the', 'head', 'was', 'like', 'being', 'at', 'a', 'tennis', 'match', ',', 'watching', 'the', 'action', 'and', 'listening', 'to', 'the', 'arguments', 'between', 'him', 'at', 'the', 'end', 'and', 'Mom', 'over', 'at', 'the', 'stove.When', 'the', 'telephone', 'rang', ',', 'Dad', 'didn', '’', 't', 'pick', 'it', 'up', ',', 'even', 'though', 'he', 'was', 'sitting', 'next', 'to', 'it', '.', 'Mom', 'walked', 'over', 'behind', 'him', 'and', 'answered', 'the', 'call.', '“', 'Hello', '?', 'Hi', ',', 'Bobbie', '.', 'What', '?', 'What', 'are', 'you', 'talking', 'about', '?', 'How', 'did', 'this', 'happen', '?', 'Oh', ',', 'my', 'God', ',', 'I', 'don', '’', 't', 'believe', 'it', '!', 'When', 'did', 'they', 'find', 'her', '?', 'Oh', ',', 'poor', 'Connie', ',', 'how', 'will', 'she', 'handle', 'this', '?', '”', 'Mom', '’', 's', 'voice', 'kept', 'getting', 'higher', 'and', 'higher', 'in', 'pitch', ',', 'and', 'the', 'tears', 'were', 'starting', 'to', 'flow', '. ...
# 5823

# %%
from collections import Counter

word_freq = Counter(tokens).most_common(100)

print(len(word_freq))

vocab = [w for w, _ in word_freq]
print(vocab)
# Out:
# 100
# ['the', ',', '.', 'of', 'a', 'to', 'and', 'was', 'in', 'I', 'on', 'that', 'at', 'his', 'is', 'as', 'with', 'by', 'The', 'their', 'out', 'my', 'or', 'for', 'from', 'have', 'one', 'it', 'her', 'be', 'like', 'are', 'he', 'all', '?', 'would', 'an', 'but', 'up', 'you', 'this', 'over', 'not', 'He', 'home', 'him', 'she', 'children', 'me', 'were', 'down', 'back', 'there', 'been', '``', 'ride', 'time', 'Mom', 'who', 'off', 'had', 'It', 'them', 'into', 'girl', 'too', 'about', 'house', 'our', 'people', 'small', 'other', 'even', 'door', 'around', 'A', "'s", 'away', '“', '”', 'being', 'Dad', 'room', 'its', 'through', 'As', 'face', 'corner', 'just', 'each', 'outside', 'more', 'day', 'along', 'little', 'where', 'almost', 'we', 'could', 'if']

# %%
new_tokens = [_ if _ in vocab else '<unk>' for _ in tokens]
print(new_tokens)
# Out:
# ['The', '<unk>', 'was', '<unk>', 'and', '<unk>', 'as', '<unk>', 'at', 'this', 'time', 'of', '<unk>', '.', 'The', '<unk>', 'were', 'all', '<unk>', ',', 'with', '<unk>', '<unk>', 'just', 'a', '<unk>', '.', '<unk>', 'was', 'just', 'a', '<unk>', '<unk>', 'away', ',', 'and', 'all', 'the', '<unk>', 'were', '<unk>', '<unk>', 'to', '<unk>', 'home', 'from', '<unk>', 'for', 'a', '<unk>', '<unk>', 'and', 'to', 'the', '“', '<unk>', '<unk>', '”', 'on', '<unk>', '<unk>', '.', '<unk>', '<unk>', 'to', '<unk>', 'to', '<unk>', 'was', '<unk>', ',', 'but', '<unk>', 'by', 'the', 'time', '<unk>', 'was', 'over', ',', '<unk>', 'to', '<unk>', 'was', 'a', '<unk>', '<unk>', '.', '<unk>', 'to', 'the', '<unk>', 'to', '<unk>', '“', '<unk>', '”', 'from', '<unk>', 'and', ',', 'to', '<unk>', '<unk>', '<unk>', '<unk>', 'that', '<unk>', '<unk>', '<unk>', '.', '<unk>', '<unk>', ',', '<unk>', 'were', '<unk>', 'for', '<unk>', '<unk>', '<unk>', ',', 'not', '<unk>', 'for', 'each', 'and', '<unk>', '<unk>', '.', '<unk>', 'one', 'there', 'was', '<unk>', ',', 'and', 'being', 'too', '<unk>', 'was', '<unk>', 'the', '<unk>', '.', '<unk>', '<unk>', ',', 'the', '<unk>', 'outside', 'of', 'home', 'was', 'more', '<unk>', 'and', '<unk>', ',', 'not', '<unk>', ',', '<unk>', 'and', '<unk>', '.', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', ',', 'it', 'was', '<unk>', '<unk>', 'away', 'and', '<unk>', 'to', 'be', 'too', '<unk>', 'about', '.', '<unk>', 'Dad', '<unk>', '<unk>', 'too', '<unk>', 'to', '<unk>', ',', 'and', 'Mom', 'just', '<unk>', 'at', '<unk>', 'all', 'the', 'time', ',', 'being', 'home', 'was', 'not', '<unk>', 'a', '<unk>', '<unk>', '<unk>', 'outside', 'in', 'the', '<unk>', 'or', 'at', 'a', '<unk>', '<unk>', '<unk>', 'house', 'was', 'the', '<unk>', 'for', '<unk>', 'of', '<unk>', '<unk>', '.', '<unk>', '<unk>', '<unk>', 'that', '<unk>', 'on', 'our', '<unk>', ',', 'and', '<unk>', 'for', 'the', '<unk>', '<unk>', 'people', 'who', '<unk>', 'at', 'the', '<unk>', 'of', 'the', '<unk>', ',', '<unk>', 'was', '<unk>', 'to', '<unk>', '.', '<unk>', 'a', 'small', '<unk>', '<unk>', ',', 'the', '<unk>', '<unk>', 'to', 'be', '<unk>', 'at', 'that', 'time', 'of', '<unk>', 'was', '<unk>', 'on', 'a', '<unk>', 'or', '<unk>', '<unk>', 'from', '<unk>', 'out', 'too', '<unk>', '.', '<unk>', '<unk>', 'like', 'that', '<unk>', ',', 'the', '<unk>', '<unk>', 'was', 'to', 'be', 'home', '<unk>', '<unk>', 'that', '<unk>', '<unk>', 'was', '<unk>', '.', '<unk>', 'were', 'all', 'home', ',', 'and', 'the', 'day', 'was', '<unk>', 'off', '<unk>', '<unk>', '.', '<unk>', 'of', 'the', '<unk>', 'were', '<unk>', ',', '<unk>', '<unk>', 'were', '<unk>', ',', 'and', 'Mom', 'and', 'Dad', 'were', '<unk>', '<unk>', ',', 'not', '<unk>', 'or', '<unk>', 'at', 'each', 'other', '.', 'Dad', 'was', '<unk>', 'at', 'his', '<unk>', 'at', 'the', '<unk>', 'room', '<unk>', ',', 'and', 'Mom', 'was', 'in', 'the', '<unk>', '<unk>', '<unk>', '.', '<unk>', '<unk>', 'along', 'the', '<unk>', 'with', 'Dad', 'at', 'the', '<unk>', 'was', 'like', 'being', 'at', 'a', '<unk>', '<unk>', ',', '<unk>', 'the', '<unk>', 'and', '<unk>', 'to', 'the', '<unk>', '<unk>', 'him', 'at', 'the', '<unk>', 'and', 'Mom', 'over', 'at', 'the', '<unk>', 'the', '<unk>', '<unk>', ',', 'Dad', '<unk>', '<unk>', '<unk>', '<unk>', 'it', 'up', ',', 'even', '<unk>', 'he', 'was', '<unk>', '<unk>', 'to', 'it', '.', 'Mom', '<unk>', 'over', '<unk>', 'him', 'and', '<unk>', 'the', '<unk>', '“', '<unk>', '?', '<unk>', ',', '<unk>', '.', '<unk>', '?', '<unk>', 'are', 'you', '<unk>', 'about', '?', '<unk>', '<unk>', 'this', '<unk>', '?', '<unk>', ',', 'my', '<unk>', ',', 'I', '<unk>', '<unk>', '<unk>', '<unk>', 'it', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', 'her', '?', '<unk>', ',', '<unk>', '<unk>', ',', '<unk>', '<unk>', 'she', '<unk>', 'this', '?', '”', 'Mom', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', 'and', '<unk>', 'in', '<unk>', ',', 'and', 'the', '<unk>', 'were', '<unk>', 'to', '<unk>', '.', '<unk>', '<unk>', 'of', '<unk>', 'was', '<unk>', 'out', 'of', '<u ...

# %%
from nltk.util import ngrams
fourgrams = list(ngrams(new_tokens, 4))

# %%
from collections import defaultdict, Counter

# Assuming trigrams is a list of 4-grams
fourgram_count = defaultdict(Counter)

for fourgram in fourgrams:
    # Assuming fourgram is a tuple (word1, word2, word3, word4)
    key = (fourgram[0], fourgram[1], fourgram[2])
    value = fourgram[3]
    fourgram_count[key][value] += 1

# %%
fourgram_count
# Out:
# defaultdict(collections.Counter,
#             {('The', '<unk>', 'was'): Counter({'<unk>': 2, 'a': 1}),
#              ('<unk>',
#               'was',
#               '<unk>'): Counter({'and': 3,
#                       ',': 2,
#                       'the': 1,
#                       'to': 1,
#                       'on': 1,
#                       '.': 1,
#                       'out': 3,
#                       '<unk>': 4,
#                       'for': 1,
#                       'like': 1,
#                       'in': 1,
#                       'with': 1,
#                       'into': 1,
#                       'by': 1,
#                       'a': 1}),
#              ('was', '<unk>', 'and'): Counter({'<unk>': 2, 'he': 1}),
#              ('<unk>',
#               'and',
#               '<unk>'): Counter({'as': 2,
#                       ',': 6,
#                       '.': 6,
#                       'to': 5,
#                       'in': 2,
#                       'where': 1,
#                       'the': 2,
#                       'a': 4,
#                       'out': 1,
#                       '<unk>': 24,
#                       'it': 2,
#                       'away': 1,
#                       'of': 3,
#                       'him': 2,
#                       'my': 1,
#                       'that': 1,
#                       'all': 1,
#                       'and': 1,
#                       'his': 1,
#                       'off': 1,
#                       'them': 2,
#                       'her': 1,
#                       'girl': 1,
#                       'on': 1,
#                       'up': 1,
#                       'was': 1}),
#              ('and', '<unk>', 'as'): Counter({'<unk>': 1, 'he': 1}),
#              ('<unk>', 'as', '<unk>'): Counter({'at': 1, 'as': 1, '<unk>': 1}),
#              ('as', '<unk>', 'at'): Counter({'this': 1}),
#              ('<unk>', 'at', 'this'): Counter({'time': 1}),
#              ('at', 'this', 'time'): Counter({'of': 1}),
#              ('this', 'time', 'of'): Counter({'<unk>': 1}),
#              ('time', 'of', '<unk>'): Counter({'.': 1, 'was': 1}),
#              ('of',
#               '<unk>',
#               '.'): Counter({'The': 1, 'He': 1, 'As': 1, '<unk>': 5}),
#              ('<unk>', '.', 'The'): Counter({'<unk>': 22, 'back': 1}),
#              ('.',
#               'The',
#               '<unk>'): Counter({'were': 1,
#                       'that': 1,
#                       '<unk>': 12,
#                       'of': 6,
#                       'was': 1,
#                       'are': 1,
#                       'door': 1,
#                       'is': 1}),
#              ('The', '<unk>', 'were'): Counter({'all': 1}),
#              ('<unk>', 'were', 'all'): Counter({'<unk>': 1, 'home': 1}),
#              ('were', 'all', '<unk>'): Counter({',': 1}),
#              ('all', '<unk>', ','): Counter({'with': 1}),
#              ('<unk>', ',', 'with'): Counter({'<unk>': 2, 'the': 1, 'a': 1}),
#              (',', 'with', '<unk>'): Counter({'<unk>': 2}),
#              ('with',
#               '<unk>',
#               '<unk>'): Counter({'just': 1, '<unk>': 5, 'from': 1, ',': 1}),
#              ('<unk>', '<unk>', 'just'): Counter({'a': 1}),
#              ('<unk>', 'just', 'a'): Counter({'<unk>': 2}),
#              ('just', 'a', '<unk>'): Counter({'.': 1, '<unk>': 2}),
#              ('a',
#               '<unk>',
#               '.'): Counter({'<unk>': 4,
#                       'Dad': 1,
#                       'The': 1,
#                       'He': 4,
#                       'A': 2,
#                       'It': 2}),
#              ('<unk>',
#               '.',
#               '<unk>'): Counter({'was': 1,
#                       '<unk>': 49,
#                       'to': 3,
#                       'one': 3,
#                       'a': 3,
#                       'were': 1,
#                       'of': 2,
#                       '?': 1,
#                       'just': 1,
#                       'time': 1,
#                       'the': 5,
#                       'in': 3,
#                       ',': 9,
#                       'by': 1,
#                       'is': 3,
#                       'me': 1,
#                       'at': 2,
#                       'almost': 1,
#                       'there': 1,
#                       'and': 1,
#                       'I': 2,
#                       'have': 1,
#                       "'s": 1,
#                       'with': 1,
#                       'back': 1,
#                       'his': 1,
#                       'are': 1,
#                       'on': 1,
#                       'her': 1,
#                       'through': 1,
#                       'out': 1,
#                       'she': 1,
#                       'He': 1}),
#              ('.', '<unk>', 'was'): Counter({'just': 1}),
#              ('<unk>', 'was', 'just'): Counter({'a': 1}),
#              ('was', 'just', 'a'): Counter({'<unk>': 1}),
#              ('a',
#               '<unk>',
#               '<unk>'): Counter({'away': 1,
#                       'and': 4,
#                       '.': 11,
#                       '<unk>': 20,
#                       ',': 11,
#                       'to': 2,
#                       'be': 1,
#                       'of': 8,
#                       'we': 1,
#                       'in': 1,
#                       'at': 2,
#                       '?': 2,
#                       'who': 1,
#                       'with': 4,
#                       'or': 2,
#                       'girl': 1,
#                       'by': 1,
#                       'as': 2,
#                       "'s": 1,
#                       'around': 1}),
#              ('<unk>',
#               '<unk>',
#               'away'): Counter({',': 1, 'and': 1, 'in': 1, 'from': 1}),
#              ('<unk>', 'away', ','): Counter({'and': 1, '<unk>': 1}),
#              ('away', ',', 'and'): Counter({'all': 1}),
#              (',', 'and', 'all'): Counter({'the': 1}),
#              ('and', 'all', 'the'): Counter({'<unk>': 1}),
#              ('all',
#               'the',
#               '<unk>'): Counter({'were': 1, 'was': 1, '<unk>': 2}),
#              ('the', '<unk>', 'were'): Counter({'<unk>': 3}),
#              ('<unk>',
#               'were',
#               '<unk>'): Counter({'<unk>': 1,
#                       'for': 1,
#                       ',': 2,
#                       'to': 1,
#                       'like': 1}),
#              ('were', '<unk>', '<unk>'): Counter({'to': 1, ',': 1}),
#              ('<unk>',
#               '<unk>',
#               'to'): Counter({'<unk>': 33,
#                       'be': 2,
#                       'it': 1,
#                       'home': 1,
#                       'this': 2,
#                       'have': 2,
#                       'the': 8,
#                       'a': 2,
#                       'each': 1,
#                       'his': 1,
#                       'their': 1}),
#              ('<unk>',
#               'to',
#               '<unk>'): Counter({'home': 2,
#                       'to': 3,
#                       'was': 2,
#                       '“': 1,
#                       ',': 4,
#                       '.': 6,
#                       'out': 2,
#                       'in': 2,
#                       'down': 1,
#                       'Mom': 1,
#                       'that': 1,
#                       'if': 1,
#                       '<unk>': 16,
#                       'a': 4,
#                       'the': 13,
#                       'an': 1,
#                       'their': 3,
#                       'me': 1,
#                       'our': 1,
#                       'up': 2,
#                       'it': 1,
#                       'for': 1,
#                       'him': 2,
#                       'her': 1,
#                       'on': 1,
#                       'and': 2,
#                       'even': 1,
#                       'them': 1,
#                       'each': 1}),
#              ('to', '<unk>', 'home'): Counter({'from': 1, '.': 1}),
#              ('<unk>', 'home', 'from'): Counter({'<unk>': 1}),
#              ('home', 'from', '<unk>'): Counter({'for': 1}),
#              ('from', '<unk>', 'for'): Counter({'a': 1}),
#              ('<unk>', 'for', 'a'): Counter({'<unk>': 1}),
#              ('for', 'a', '<unk>'): Counter({'<unk>': 2}),
#              ('<unk>',
#               '<unk>',
#               'and'): Counter({'to': 1,
#                       '<unk>': 34,
#                       'be': 1,
#                       'not': 1,
#                       'the': 2,
#                       'have': 2,
#                       'I': 1,
#                       'a': 2,
#                       ',': 1,
#                       'he': 1,
#                       'is': 1,
#                       'his': 1,
#                       'her': 1,
#                       'children': 1,
#                       'ride': 1}),
#              ('<unk>', 'and', 'to'): Counter({'the': 1}),
#              ('and', 'to', 'the'): Counter({'“': 1}),
#              ('to', 'the', '“'): Counter({'<unk>': 1}),
#              ('the', '“', '<unk>'): Counter({'<unk>': 1}),
#              ('“', '<unk>', '<unk>'): Counter({'”': 1}),
#              ('<unk>', '<unk>', '”'): Counter({'on': 1, '<unk>': 2, 'or': 1}),
#              ('<unk>', '”', 'on'): Counter({'<unk>': 1}),
#              ('”', 'on', '<unk>'): Counter({'<unk>': 1}),
#              ('on', '<unk>', '<unk>'): Counter({'.': 2, '<unk>': 1, 'not': 1}),
#              ('<unk>',
#               '<unk>',
#               '.'): Counter({'<unk>': 54,
#                       'The': 10,
#                       'He': 6,
#                       'As': 3,
#                       '``': 4,
#                       'A': 2,
#                       'I': 4,
#                       'It': 3}),
#              ('.',
#               '<unk>',
#               '<unk>'): Counter({'to': 4,
#                       ',': 3,
#                       '<unk>': 22,
#                       'like': 1,
#                       'along': 1,
#                       'of': 3,
#                       'it': 1,
#                       'outside': 1,
#                       'was': 2,
#                       'away': 1,
#                       'the': 4,
#                       'that': 1,
#                       'were': 1,
#                       'house': 1,
#                       'with': 1,
#                       'a': 1,
#                       'and': 3,
#                       'girl': 1,
#                       'his': 1,
#                       'out': 1,
#                       'over': 1,
#                       'at': 2,
#                       'in': 2,
#                       'her': 1,
#                       'are': 1,
#                       '.': 1}),
#              ('to', '<unk>', 'to'): Counter({'<unk>': 2, '.': 1, 'the': 1}),
#              ('to', '<unk>', 'was'): Counter({'<unk>': 1, 'a': 1}),
#              ('was', '<unk>', ','): Counter({'but': 1, 'and': 2, '<unk>': 1}),
#              ('<unk>',
#               ',',
#               'but'): Counter({'<unk>': 5,
#                       'I': 1,
#                       'he': 1,
#                       'even': 1,
#                       'not': 2,
#                       'it': 1,
#                       'to': 1}),
#              (',',
#               'but',
#               '<unk>'): Counter({'by': 1, '<unk>': 3, 'I': 1, 'to': 1}),
#              ('but', '<unk>', 'by'): Counter({'the': 1}),
#              ('<unk>', 'by', 'the'): Counter({'time': 1, '<unk>': 5}),
#              ('by', 'the', 'time'): Counter({'<unk>': 1}),
#              ('the', 'time', '<unk>'): Counter({'was': 1}),
#              ('time', '<unk>', 'was'): Counter({'over': 1}),
#              ('<unk>', 'was', 'over'): Counter({',': 1}),
#              ('was', 'over', ','): Counter({'<unk>': 1, 'I': 1}),
#              ('over', ',', '<unk>'): Counter({'to': 1}),
#              (',', '<unk>', 'to'): Counter({'<unk>': 4, 'be': 1}),
#              ('<unk>', 'was', 'a'): Counter({'<unk>': 4}),
#              ('was',
#               'a',
#               '<unk>'): Counter({'<unk>': 6, 'of': 1, ',': 2, 'with': 1}),
#              ('.', '<unk>', 'to'): Counter({'the': 2, '<unk>': 1}),
#              ('<unk>',
#               'to',
#               'the'): Counter({'<unk>': 17, 'back': 2, 'other': 1}),
#              ('to',
#               'the',
#               '<unk>'): Counter({'to': 2,
#                       '<unk>': 9,
#                       'and': 1,
#                       'room': 1,
#                       ',': 3,
#                       'of': 1,
#                       '.': 3}),
#              ('the',
#               '<unk>',
#               'to'): Counter({'<unk>': 6,
#                       'about': 1,
#                       'be': 1,
#                       'ride': 1,
#                       'the': 2}),
#              ('to', '<unk>', '“'): Counter({'<unk>': 1}),
#              ('<unk>', '“', '<unk>'): Counter({'”': 2, '?': 1, ',': 2}),
#              ('“', '<unk>', '”'): Counter({'from': 1, '<unk>': 1}),
#              ('<unk>', '”', 'from'): Counter({'<unk>': 1}),
#              ('”', 'from', '<unk>'): Counter({'and': 1}),
#              ('from', '<unk>', 'and'): Counter({',': 1}),
#              ('<unk>', 'and', ','): Counter({'to': 1, 'as': 1, '<unk>': 1}),
#              ('and', ',', 'to'): Counter({'<unk>': 1}),
#              (',', 'to', '<unk>'): Counter({'<unk>': 2, ',': 1, 'her': 1}),
#              ('to',
#               '<unk>',
#               '<unk>'): Counter({'<unk>': 10,
#                       'the': 1,
#                       'to': 2,
#                       'up': 1,
#                       'or': 1,
#                       'of': 1,
#                       'and': 1,
#                       '.': 2,
#                       'his': 1,
#                       ',': 1}),
#              ('<unk>',
#               '<unk>',
#               '<unk>'): Counter({'<unk>': 109,
#                       'that': 5,
#                       '.': 23,
#                       ',': 32,
#                       'outside': 1,
#                       'house': 2,
#                       'it': 2,
#                       'her': 2,
#                       'and': 22,
#                       'each': 1,
#                       'being': 2,
#                       '”': 1,
#                       'children': 1,
#                       'this': 2,
#                       'of': 13,
#                       'up': 2,
#                       'to': 20,
#                       'with': 6,
#                       'his': 1,
#                       'like': 1,
#                       'the': 13,
#                       'a': 8,
#                       'out': 4,
#                       'over': 1,
#                       'there': 2,
#                       'are': 1,
#                       'is': 4,
#                       '“': 2,
#                       'down': 1,
#                       'have': 2,
#                       'from': 5,
#                       'you': 2,
#                       'in': 4,
#                       'off': 1,
#                       'ride': 1,
#                       'me': 3,
#                       'through': 2,
#                       'I': 3,
#                       'about': 1,
#                       'on': 4,
#                       'by': 5,
#                       'people': 1,
#                       'along': 2,
#                       'into': 1,
#                       'around': 2,
#                       'at': 1,
#                       'almost': 1,
#                       'as': 2,
#                       'or': 1,
#                       'their': 1,
#                       'away': 1,
#                       'was': 3,
#                       'for': 1,
#                       'one': 1,
#                       'he': 1}),
#              ('<unk>',
#               '<unk>',
#               'that'): Counter({'<unk>': 8,
#                       'the': 1,
#                       'I': 1,
#                       'people': 1,
#                       'was': 1}),
#              ('<unk>',
#               'that',
#               '<unk>'): Counter({'<unk>': 8,
#                       'on': 1,
#                       'had': 1,
#                       'and': 1,
#                       'be': 1,
#                       'of': 1,
#                       'to': 2,
#                       'been': 1,
#                       'was': 1}),
#              ('that',
#               '<unk>',
#               '<unk>'): Counter({'<unk>': 6,
#                       'was': 1,
#                       'the': 1,
#                       'who': 1,
#                       'on': 1}),
#              ('<unk>',
#               '<unk>',
#               ','): Counter({'<unk>': 36,
#                       'not': 2,
#                       'the': 8,
#                       'it': 1,
#                       'Dad': 1,
#                       'but': 5,
#                       'she': 1,
#                       '“': 1,
#                       'even': 2,
#                       'we': 1,
#                       'I': 5,
#                       'a': 8,
#                       'and': 6,
#                       'you': 1,
#                       'an': 1,
#                       'with': 1,
#                       'where': 1,
#                       'or': 1,
#                       'to': 1,
#                       'one': 1,
#                       'there': 1,
#                       'is': 1,
#                       'almost': 1,
#                       '``': 1,
#                       'his': 1,
#                       'her': 1,
#                       'children': 1,
#                       'about': 1}),
#              ('<unk>',
#               ',',
#               '<unk>'): Counter({'were': 2,
#                       'and': 3,
#                       'was': 1,
#                       '<unk>': 53,
#                       'the': 4,
#                       '.': 1,
#                       'in': 6,
#                       'out': 3,
#                       'that': 2,
#                       'a': 1,
#                       'you': 1,
#                       'at': 2,
#                       'are': 1,
#                       ',': 6,
#                       'people': 1,
#                       'is': 2,
#                       'by': 3,
#                       'of': 3,
#                       'to': 3,
#                       'all': 1,
#                       'his': 1,
#                       'face': 1,
#                       'her': 3,
#                       'an': 2,
#                       'over': 1,
#                       'even': 1,
#                       'them': 1,
#                       'as': 1,
#                       'on': 2}),
#              (',', '<unk>', 'were'): Counter({'<unk>': 2}),
#              ('were', '<unk>', 'for'): Counter({'<unk>': 1}),
#              ('<unk>',
#               'for',
#               '<unk>'): Counter({'<unk>': 2, 'of': 1, 'to': 1}),
#              ('for', '<unk>', '<unk>'): Counter({'<unk>': 2, '?': 1}),
#              ('<unk>', ',', 'not'): Counter({'<unk>': 3}),
#              (',', 'not', '<unk>'): Counter({'for': 1, ',': 1, 'or': 1}),
#              ('not', '<unk>', 'for'): Counter({'each': 1}),
#              ('<unk>', 'for', 'each'): Counter({'and': 1}),
#              ('for', 'each', 'and'): Counter({'<unk>': 1}),
#              ('each', 'and', '<unk>'): Counter({'<unk>': 2}),
#              ('and',
#               '<unk>',
#               '<unk>'): Counter({'.': 6,
#                       'could': 1,
#                       'of': 1,
#                       'one': 1,
#                       'from': 1,
#                       'with': 1,
#                       '<unk>': 12,
#                       ',': 2,
#                       'was': 1,
#                       'to': 1,
#                       'the': 2,
#                       'like': 1,
#                       'his': 1}),
#              ('.',
#               '<unk>',
#               'one'): Counter({'there': 1, 'was': 1, 'corner': 1, 'of': 1}),
#              ('<unk>', 'one', 'there'): Counter({'was': 1}),
#              ('one', 'there', 'was'): Counter({'<unk>': 1}),
#              ('there', 'was', '<unk>'): Counter({',': 1}),
#              ('<unk>',
#               ',',
#               'and'): Counter({'being': 1,
#                       'Mom': 3,
#                       '<unk>': 7,
#                       'the': 4,
#                       'his': 1,
#                       'my': 1,
#                       'one': 1,
#                       'I': 1,
#                       'a': 1,
#                       'she': 1}),
#              (',', 'and', 'being'): Counter({'too': 1}),
#              ('and', 'being', 'too'): Counter({'<unk>': 1}),
#              ('being', 'too', '<unk>'): Counter({'was': 1}),
#              ('too', '<unk>', 'was'): Counter({'<unk>': 1}),
#              ('was', '<unk>', 'the'): Counter({'<unk>': 1}),
#              ('<unk>',
#               'the',
#               '<unk>'): Counter({'.': 6,
#                       'and': 3,
#                       '<unk>': 28,
#                       '“': 1,
#                       'of': 11,
#                       ',': 9,
#                       'on': 2,
#                       'as': 2,
#                       "'s": 3,
#                       'in': 1,
#                       'out': 1,
#                       'is': 2,
#                       'room': 1,
#                       'corner': 1,
#                       'to': 2,
#                       'where': 1,
#                       'outside': 1,
#                       'or': 1,
#                       'people': 1,
#                       'like': 1}),
#              ('the',
#               '<unk>',
#               '.'): Counter({'<unk>': 14,
#                       'The': 3,
#                       'It': 1,
#                       'As': 3,
#                       'A': 2,
#                       'He': 1,
#                       'and': 1}),
#              ('<unk>',
#               ',',
#               'the'): Counter({'<unk>': 23, 'other': 1, 'children': 1}),
#              (',',
#               'the',
#               '<unk>'): Counter({'outside': 1,
#                       '<unk>': 17,
#                       'of': 2,
#                       'to': 1,
#                       ',': 1,
#                       'in': 1,
#                       "'s": 1,
#                       'we': 1}),
#              ('the', '<unk>', 'outside'): Counter({'of': 1, 'and': 1}),
#              ('<unk>', 'outside', 'of'): Counter({'home': 1}),
#              ('outside', 'of', 'home'): Counter({'was': 1}),
#              ('of', 'home', 'was'): Counter({'more': 1}),
#              ('home', 'was', 'more'): Counter({'<unk>': 1}),
#              ('was', 'more', '<unk>'): Counter({'and': 1}),
#              ('more', '<unk>', 'and'): Counter({'<unk>': 1}),
#              ('and',
#               '<unk>',
#               ','): Counter({'not': 1,
#                       'the': 2,
#                       '<unk>': 2,
#                       'he': 1,
#                       '``': 1}),
#              ('not', '<unk>', ','): Counter({'<unk>': 1}),
#              (',', '<unk>', 'and'): Counter({'<unk>': 2, 'not': 1}),
#              ('and', '<unk>', '.'): Counter({'<unk>': 2, 'A': 1, 'The': 2}),
#              ('<unk>', ',', 'it'): Counter({'was': 1}),
#              (',', 'it', 'was'): Counter({'<unk>': 1}),
#              ('it', 'was', '<unk>'): Counter({'<unk>': 1}),
#              ('was',
#               '<unk>',
#               '<unk>'): Counter({'away': 1,
#                       'to': 2,
#                       'this': 1,
#                       'not': 1,
#                       '<unk>': 2,
#                       'along': 1,
#                       'with': 1}),
#              ('<unk>', 'away', 'and'): Counter({'<unk>': 1}),
#              ('away', 'and', '<unk>'): Counter({'to': 1}),
#              ('and',
#               '<unk>',
#               'to'): Counter({'be': 1,
#                       'the': 2,
#                       'my': 1,
#                       'have': 1,
#                       '<unk>': 2}),
#              ('<unk>',
#               'to',
#               'be'): Counter({'too': 1, '<unk>': 3, 'more': 1, 'of': 1}),
#              ('to', 'be', 'too'): Counter({'<unk>': 1}),
#              ('be', 'too', '<unk>'): Counter({'about': 1}),
#              ('too', '<unk>', 'about'): Counter({'.': 1}),
#              ('<unk>', 'about', '.'): Counter({'<unk>': 1}),
#              ('about', '.', '<unk>'): Counter({'Dad': 1}),
#              ('.', '<unk>', 'Dad'): Counter({'<unk>': 1}),
#              ('<unk>', 'Dad', '<unk>'): Counter({'<unk>': 1}),
#              ('Dad', '<unk>', '<unk>'): Counter({'too': 1, '<unk>': 2}),
#              ('<unk>', '<unk>', 'too'): Counter({'<unk>': 1}),
#              ('<unk>', 'too', '<unk>'): Counter({'to': 3, ',': 1, '<unk>': 1}),
#              ('too', '<unk>', 'to'): Counter({'<unk>': 2, 'the': 1}),
#              ('to', '<unk>', ','): Counter({'and': 2, 'the': 1, '<unk>': 4}),
#              (',', 'and', 'Mom'): Counter({'just': 1, 'and': 1, 'was': 1}),
#              ('and', 'Mom', 'just'): Counter({'<unk>': 1}),
#              ('Mom', 'just', '<unk>'): Counter({'at': 1}),
#              ('just', '<unk>', 'at'): Counter({'<unk>': 1}),
#              ('<unk>', 'at', '<unk>'): Counter({'all': 1, ',': 1, '<unk>': 1}),
#              ('at', '<unk>', 'all'): Counter({'the': 1}),
#              ('<unk>', 'all', 'the'): Counter({'time': 1, 'children': 1}),
#              ('all', 'the', 'time'): Counter({',': 1}),
#              ('the', 'time', ','): Counter({'being': 1}),
#              ('time', ',', 'being'): Counter({'home': 1}),
#              (',', 'being', 'home'): Counter({'was': 1}),
#              ('being', 'home', 'was'): Counter({'not': 1}),
#              ('home', 'was', 'not'): Counter({'<unk>': 1}),
#              ('was', 'not', '<unk>'): Counter({'a': 1}),
#              ('not', '<unk>', 'a'): Counter({'<unk>': 1}),
#              ('<unk>',
#               'a',
#               '<unk>'): Counter({'<unk>': 19,
#                       '.': 7,
#                       'of': 4,
#                       ',': 7,
#                       'for': 1,
#                       'in': 1,
#                       'out': 1,
#                       'and': 1}),
#              ('<unk>',
#               '<unk>',
#               'outside'): Counter({'in': 1, 'could': 1, 'was': 1}),
#              ('<unk>', 'outside', 'in'): Counter({'the': 1}),
#              ('outside', 'in', 'the'): Counter({'<unk>': 1}),
#              ('in',
#               'the',
#               '<unk>'): Counter({'or': 1,
#                       '<unk>': 7,
#                       '?': 1,
#                       'door': 1,
#                       'room': 1,
#                       'of': 2,
#                       ',': 1,
#                       'corner': 3,
#                       '.': 1}),
#              ('the', '<unk>', 'or'): Counter({'at': 1, 'more': 1}),
#              ('<unk>', 'or', 'at'): Counter({'a': 1}),
#              ('or', 'at', 'a'): Counter({'<unk>': 1}),
#              ('at', 'a', '<unk>'): Counter({'<unk>': 4}),
#              ('<unk>',
#               '<unk>',
#               'house'): Counter({'was': 1, 'would': 1, '<unk>': 1}),
#              ('<unk>', 'house', 'was'): Counter({'the': 1}),
#              ('house', 'was', 'the'): Counter({'<unk>': 1}),
#              ('was', 'the', '<unk>'): Counter({'for': 1, '<unk>': 1}),
#              ('the', '<unk>', 'for'): Counter({'<unk>': 2, 'the': 2}),
#              ('for', '<unk>', 'of'): Counter({'<unk>': 1}),
#              ('<unk>',
#               'of',
#               '<unk>'): Counter({'<unk>': 34,
#                       'was': 1,
#                       'our': 1,
#                       'and': 6,
#                       'like': 2,
#                       '.': 7,
#                       'or': 1,
#                       'about': 1,
#                       'you': 1,
#                       'the': 1,
#                       ',': 11,
#                       'children': 1,
#                       'of': 2,
#                       'who': 2}),
#              ('of',
#               '<unk>',
#               '<unk>'): Counter({'.': 2,
#                       '<unk>': 14,
#                       'outside': 1,
#                       'at': 1,
#                       'to': 3,
#                       'by': 1,
#                       'and': 2,
#                       'on': 2,
#                       'the': 2,
#                       ',': 3,
#                       'as': 1,
#                       'are': 1,
#                       'them': 1,
#                       'through': 1,
#                       'had': 1}),
#              ('that', '<unk>', 'on'): Counter({'our': 1}),
#              ('<unk>', 'on', 'our'): Counter({'<unk>': 1}),
#              ('on', 'our', '<unk>'): Counter({',': 1}),
#              ('our', '<unk>', ','): Counter({'and': 1}),
#              (',',
#               'and',
#               '<unk>'): Counter({'for': 1,
#                       '<unk>': 3,
#                       'I': 1,
#                       'to': 1,
#                       'are': 1,
#                       'away': 1}),
#              ('and', '<unk>', 'for'): Counter({'the': 1}),
#              ('<unk>', 'for', 'the'): Counter({'<unk>': 7}),
#              ('for',
#               'the',
#               '<unk>'): Counter({'<unk>': 3,
#                       'and': 1,
#                       ',': 1,
#                       'to': 2,
#                       'of': 1,
#                       'was': 1}),
#              ('the',
#               '<unk>',
#               '<unk>'): Counter({'people': 1,
#                       'to': 5,
#                       'was': 2,
#                       '<unk>': 41,
#                       'him': 1,
#                       ',': 14,
#                       'a': 1,
#                       'through': 1,
#                       'our': 1,
#                       'of': 21,
#                       'the': 2,
#                       'like': 2,
#                       '.': 8,
#                       '?': 1,
#                       'you': 2,
#                       'out': 2,
#                       'it': 1,
#                       'me': 1,
#                       'that': 3,
#                       'its': 1,
#                       'I': 1,
#                       'in': 2,
#                       'room': 1,
#                       'their': 1,
#                       'at': 2,
#                       'and': 5,
#                       'is': 1,
#                       'down': 2,
#                       'as': 2,
#                       'with': 1,
#                       'his': 1,
#                       'by': 1,
#                       'not': 1,
#                       'or': 1,
#                       'children': 1,
#                       'but': 1,
#                       'into': 1}),
#              ('<unk>',
#               '<unk>',
#               'people'): Counter({'who': 1, 'as': 1, 'are': 1}),
#              ('<unk>', 'people', 'who'): Counter({'<unk>': 1}),
#              ('people', 'who', '<unk>'): Counter({'at': 1}),
#              ('who', '<unk>', 'at'): Counter({'the': 1}),
#              ('<unk>', 'at', 'the'): Counter({'<unk>': 16}),
#              ('at',
#               'the',
#               '<unk>'): Counter({'of': 5,
#                       'room': 1,
#                       'was': 1,
#                       'and': 1,
#                       'the': 1,
#                       '<unk>': 6,
#                       ',': 4,
#                       'a': 1}),
#              ('the',
#               '<unk>',
#               'of'): Counter({'the': 11,
#                       'that': 1,
#                       '<unk>': 13,
#                       'a': 3,
#                       'its': 1,
#                       'my': 1,
#                       'children': 1,
#                       'one': 1,
#                       'them': 1}),
#              ('<unk>', 'of', 'the'): Counter({'<unk>': 38, 'children': 1}),
#              ('of',
#               'the',
#               '<unk>'): Counter({',': 7,
#                       'were': 1,
#                       '.': 8,
#                       'being': 1,
#                       '<unk>': 24,
#                       'children': 1,
#                       'to': 1,
#                       'with': 1,
#                       "'s": 1,
#                       'and': 2,
#                       'for': 2,
#                       'is': 3,
#                       'of': 1,
#                       'that': 1,
#                       'at': 1}),
#              ('the',
#               '<unk>',
#               ','): Counter({'<unk>': 18,
#                       'with': 1,
#                       'the': 1,
#                       'you': 1,
#                       'but': 2,
#                       'is': 2,
#                       'we': 1,
#                       'and': 1,
#                       'a': 3,
#                       'she': 1,
#                       'to': 1,
#                       'an': 1}),
#              (',', '<unk>', 'was'): Counter({'<unk>': 1}),
#              ('was', '<unk>', 'to'): Counter({'<unk>': 2}),
#              ('to', '<unk>', '.'): Counter({'<unk>': 5, 'Dad': 1}),
#              ('.', '<unk>', 'a'): Counter({'small': 1, '<unk>': 2}),
#              ('<unk>', 'a', 'small'): Counter({'<unk>': 1}),
#              ('a',
#               'small',
#               '<unk>'): Counter({'<unk>': 1, 'to': 1, 'of': 1, ',': 1}),
#              ('small', '<unk>', '<unk>'): Counter({',': 1}),
#              ('to',
#               'be',
#               '<unk>'): Counter({'at': 1,
#                       '<unk>': 2,
#                       'through': 1,
#                       'away': 1}),
#              ('be', '<unk>', 'at'): Counter({'that': 1}),
#              ('<unk>', 'at', 'that'): Counter({'time': 1, '<unk>': 1}),
#              ('at', 'that', 'time'): Counter({'of': 1}),
#              ('that', 'time', 'of'): Counter({'<unk>': 1}),
#              ('of', '<unk>', 'was'): Counter({'<unk>': 2}),
#              ('was', '<unk>', 'on'): Counter({'a': 1}),
#              ('<unk>', 'on', 'a'): Counter({'<unk>': 4, 'corner': 1}),
#              ('on',
#               'a',
#               '<unk>'): Counter({'or': 1, '<unk>': 2, ',': 2, 'of': 1}),
#              ('a', '<unk>', 'or'): Counter({'<unk>': 3}),
#              ('<unk>',
#               'or',
#               '<unk>'): Counter({'<unk>': 6,
#                       'at': 1,
#                       'a': 1,
#                       ',': 1,
#                       'for': 1,
#                       '.': 1,
#                       'them': 1}),
#              ('or',
#               '<unk>',
#               '<unk>'): Counter({'from': 1,
#                       'we': 1,
#                       'to': 1,
#                       '<unk>': 2,
#                       'are': 1,
#                       'in': 1,
#                       ',': 1,
#                       '.': 2,
#                       'you': 1}),
#              ('<unk>',
#               '<unk>',
#               'from'): Counter({'<unk>': 2, 'the': 5, 'where': 1, 'its': 2}),
#              ('<unk>',
#               'from',
#               '<unk>'): Counter({'out': 1, 'of': 1, '<unk>': 1, 'the': 1}),
#              ('from', '<unk>', 'out'): Counter({'too': 1}),
#              ('<unk>', 'out', 'too'): Counter({'<unk>': 1}),
#              ('out', 'too', '<unk>'): Counter({'.': 1}),
#              ('too', '<unk>', '.'): Counter({'<unk>': 1}),
#              ('<unk>',
#               '<unk>',
#               'like'): Counter({'that': 1,
#                       '.': 2,
#                       'the': 1,
#                       '<unk>': 3,
#                       'a': 1}),
#              ('<unk>', 'like', 'that'): Counter({'<unk>': 1}),
#              ('like', 'that', '<unk>'): Counter({',': 1}),
#              ('that', '<unk>', ','): Counter({'the': 1, '<unk>': 1}),
#              ('<unk>',
#               '<unk>',
#               'was'): Counter({'to': 1, '<unk>': 7, 'in': 1, 'a': 1}),
#              ('<unk>', 'was', 'to'): Counter({'be': 1}),
#              ('was', 'to', 'be'): Counter({'home': 1}),
#              ('to', 'be', 'home'): Counter({'<unk>': 1}),
#              ('be', 'home', '<unk>'): Counter({'<unk>': 1}),
#              ('home', '<unk>', '<unk>'): Counter({'that': 1}),
#              ('was', '<unk>', '.'): Counter({'<unk>': 2, 'It': 1}),
#              ('.', '<unk>', 'were'): Counter({'all': 1}),
#              ('were', 'all', 'home'): Counter({',': 1}),
#              ('all', 'home', ','): Counter({'and': 1}),
#              ('home', ',', 'and'): Counter({'the': 1}),
#              (',', 'and', 'the'): Counter({'day': 1, '<unk>': 4, 'girl': 1}),
#              ('and', 'the', 'day'): Counter({'was': 1}),
#              ('the', 'day', 'was'): Counter({'<unk>': 1}),
#              ('day', 'was', '<unk>'): Counter({'off': 1}),
#              ('was', '<unk>', 'off'): Counter({'<unk>': 1}),
#              ('<unk>', 'off', '<unk>'): Counter({'<unk>': 3, 'his': 1}),
#              ('off', '<unk>', '<unk>'): Counter({'.': 1, '<unk>': 2}),
#              ('.', '<unk>', 'of'): Counter({'the': 1, '<unk>': 1}),
#              ('were', '<unk>', ','): Counter({'<unk>': 1, 'and': 1}),
#              (',',
#               '<unk>',
#               '<unk>'): Counter({'were': 1,
#                       ',': 5,
#                       'she': 1,
#                       'the': 3,
#                       '<unk>': 20,
#                       'at': 2,
#                       '”': 2,
#                       'in': 3,
#                       'of': 1,
#                       'have': 1,
#                       'up': 1,
#                       'it': 1,
#                       '.': 3,
#                       'to': 1,
#                       'by': 1,
#                       'off': 1,
#                       'on': 2,
#                       'as': 1,
#                       'and': 3,
#                       'like': 1,
#                       'down': 1,
#                       'people': 1,
#                       'around': 1,
#                       'out': 1,
#                       'he': 1}),
#              ('<unk>', '<unk>', 'were'): Counter({'<unk>': 1, 'not': 1}),
#              ('and', 'Mom', 'and'): Counter({'Dad': 1}),
#              ('Mom', 'and', 'Dad'): Counter({'were': 1}),
#              ('and', 'Dad', 'were'): Counter({'<unk>': 1}),
#              ('Dad', 'were', '<unk>'): Counter({'<unk>': 1}),
#              ('not', '<unk>', 'or'): Counter({'<unk>': 1}),
#              ('or', '<unk>', 'at'): Counter({'each': 1}),
#              ('<unk>', 'at', 'each'): Counter({'other': 1}),
#              ('at', 'each', 'other'): Counter({'.': 1}),
#              ('each', 'other', '.'): Counter({'Dad': 1, '<unk>': 2}),
#              ('other', '.', 'Dad'): Counter({'was': 1}),
#              ('.', 'Dad', 'was'): Counter({'<unk>': 2}),
#              ('Dad', 'was', '<unk>'): Counter({'at': 1, '<unk>': 1}),
#              ('was', '<unk>', 'at'): Counter({'his': 1, 'the': 1}),
#              ('<unk>', 'at', 'his'): Counter({'<unk>': 3}),
#              ('at', 'his', '<unk>'): Counter({'at': 1, 'of': 1, '.': 1}),
#              ('his', '<unk>', 'at'): Counter({'the': 1}),
#              ('the',
#               '<unk>',
#               'room'): Counter({'<unk>': 1, 'of': 1, ',': 2, 'to': 1}),
#              ('<unk>', 'room', '<unk>'): Counter({',': 1, '<unk>': 1}),
#              ('room', '<unk>', ','): Counter({'and': 1, 'the': 1}),
#              ('and', 'Mom', 'was'): Counter({'in': 1}),
#              ('Mom', 'was', 'in'): Counter({'the': 1}),
#              ('was', 'in', 'the'): Counter({'<unk>': 1}),
#              ('<unk>',
#               '<unk>',
#               'along'): Counter({'the': 2, 'like': 1, 'to': 1}),
#              ('<unk>', 'along', 'the'): Counter({'<unk>': 3}),
#              ('along',
#               'the',
#               '<unk>'): Counter({'with': 1, 'and': 1, '<unk>': 1}),
#              ('the', '<unk>', 'with'): Counter({'Dad': 1, 'a': 1}),
#              ('<unk>', 'with', 'Dad'): Counter({'at': 1}),
#              ('with', 'Dad', 'at'): Counter({'the': 1}),
#              ('Dad', 'at', 'the'): Counter({'<unk>': 1}),
#              ('the',
#               '<unk>',
#               'was'): Counter({'like': 1, 'a': 1, 'up': 1, '<unk>': 1}),
#              ('<unk>', 'was', 'like'): Counter({'being': 1}),
#              ('was', 'like', 'being'): Counter({'at': 1}),
#              ('like', 'being', 'at'): Counter({'a': 1}),
#              ('being', 'at', 'a'): Counter({'<unk>': 1}),
#              (',', '<unk>', 'the'): Counter({'<unk>': 4, 'time': 1}),
#              ('the',
#               '<unk>',
#               'and'): Counter({'<unk>': 8, 'Mom': 1, 'it': 1, 'back': 1}),
#              ('<unk>',
#               '<unk>',
#               'him'): Counter({'at': 1, 'into': 1, '<unk>': 1}),
#              ('<unk>', 'him', 'at'): Counter({'the': 1}),
#              ('him', 'at', 'the'): Counter({'<unk>': 2}),
#              ('<unk>', 'and', 'Mom'): Counter({'over': 1}),
#              ('and', 'Mom', 'over'): Counter({'at': 1}),
#              ('Mom', 'over', 'at'): Counter({'the': 1}),
#              ('over', 'at', 'the'): Counter({'<unk>': 1}),
#              ('the', '<unk>', 'the'): Counter({'<unk>': 1}),
#              ('<unk>', ',', 'Dad'): Counter({'<unk>': 1}),
#              (',', 'Dad', '<unk>'): Counter({'<unk>': 1}),
#              ('<unk>',
#               '<unk>',
#               'it'): Counter({'up': 1, '<unk>': 3, '?': 1, 'a': 1, 'down': 1}),
#              ('<unk>', 'it', 'up'): Counter({',': 1}),
#              ('it', 'up', ','): Counter({'even': 1}),
#              ('up', ',', 'even'): Counter({'<unk>': 1}),
#              (',', 'even', '<unk>'): Counter({'he': 1}),
#              ('even', '<unk>', 'he'): Counter({'was': 1}),
#              ('<unk>', 'he', 'was'): Counter({'<unk>': 1}),
#              ('he', 'was', '<unk>'): Counter({'<unk>': 1}),
#              ('<unk>', 'to', 'it'): Counter({'.': 1}),
#              ('to', 'it', '.'): Counter({'Mom': 1}),
#              ('it', '.', 'Mom'): Counter({'<unk>': 1}),
#              ('.', 'Mom', '<unk>'): Counter({'over': 1}),
#              ('Mom', '<unk>', 'over'): Counter({'<unk>': 1}),
#              ('<unk>', 'over', '<unk>'): Counter({'him': 1}),
#              ('over', '<unk>', 'him'): Counter({'and': 1}),
#              ('<unk>', 'him', 'and'): Counter({'<unk>': 1}),
#              ('him', 'and', '<unk>'): Counter({'the': 1}),
#              ('and', '<unk>', 'the'): Counter({'<unk>': 4}),
#              ('the', '<unk>', '“'): Counter({'<unk>': 1}),
#              ('“', '<unk>', '?'): Counter({'<unk>': 1}),
#              ('<unk>',
#               '?',
#               '<unk>'): Counter({',': 2,
#                       'are': 1,
#                       'it': 1,
#                       '<unk>': 5,
#                       'one': 1,
#                       'the': 1,
#                       'is': 1}),
#              ('?', '<unk>', ','): Counter({'<unk>': 2, 'my': 1}),
#              (',', '<unk>', '.'): Counter({'<unk>': 1}),
#              ('.', '<unk>', '?'): Counter({'<unk>': 1}),
#              ('?', '<unk>', 'are'): Counter({'you': 1}),
#              ('<unk>', 'are', 'you'): Counter({'<unk>': 1}),
#              ('are', 'you', '<unk>'): Counter({'about': 1}),
#              ('you', '<unk>', 'about'): Counter({'?': 1}),
#              ('<unk>', 'about', '?'): Counter({'<unk>': 1}),
#              ('about', '?', '<unk>'): Counter({'<unk>': 1}),
#              ('?',
#               '<unk>',
#               '<unk>'): Counter({'this': 1,
#                       '?': 1,
#                       '<unk>': 1,
#                       'of': 2,
#                       'are': 1,
#                       'to': 2}),
#              ('<unk>', '<unk>', 'this'): Counter({'<unk>': 5}),
#              ('<unk>',
#               'this',
#               '<unk>'): Counter({'?': 1,
#                       'over': 1,
#                       'had': 1,
#                       ',': 1,
#                       'of': 1}),
#              ('this', '<unk>', '?'): Counter({'<unk>': 1}),
#              ('<unk>', ',', 'my'): Counter({'<unk>': 2}),
#              (',', 'my', '<unk>'): Counter({',': 2}),
#              ('my',
#               '<unk>',
#               ','): Counter({'I': 1, 'but': 2, 'an': 1, 'is': 1}),
#              ('<unk>', ',', 'I'): Counter({'<unk>': 7, 'was': 1}),
#              (',',
#               'I',
#               '<unk>'): Counter({'<unk>': 3,
#                       'a': 1,
#                       'I': 1,
#                       'my': 1,
#                       'an': 1,
#                       'it': 1}),
#              ('I',
#               '<unk>',
#               '<unk>'): Counter({'<unk>': 9,
#                       'to': 1,
#                       'the': 3,
#                       'and': 1,
#                       '.': 1,
#                       'my': 1}),
#              ('<unk>', 'it', '<unk>'): Counter({'<unk>': 3, '.': 1}),
#              ('it',
#               '<unk>',
#               '<unk>'): Counter({'<unk>': 3, 'it': 1, 'with': 1, 'a': 1}),
#              ('<unk>', '<unk>', 'her'): Counter({'?': 1, ',': 1, 'are': 1}),
#              ('<unk>', 'her', '?'): Counter({'<unk>': 1}),
#              ('her', '?', '<unk>'): Counter({',': 1}),
#              ('<unk>', '<unk>', 'she'): Counter({'<unk>': 1}),
#              ('<unk>', 'she', '<unk>'): Counter({'this': 1, ',': 2}),
#              ('she', '<unk>', 'this'): Counter({'?': 1}),
#              ('<unk>', 'this', '?'): Counter({'”': 1}),
#              ('this', '?', '”'): Counter({'Mom': 1}),
#              ('?', '”', 'Mom'): Counter({'<unk>': 1}),
#              ('”', 'Mom', '<unk>'): Counter({'<unk>': 1}),
#              ('Mom', '<unk>', '<unk>'): Counter({'<unk>': 2}),
#              ('and', '<unk>', 'in'): Counter({'<unk>': 1, 'the': 1}),
#              ('<unk>',
#               'in',
#               '<unk>'): Counter({',': 8,
#                       '<unk>': 6,
#                       'and': 1,
#                       'for': 1,
#                       'a': 1,
#                       'even': 1,
#                       '.': 1}),
#              ('in',
#               '<unk>',
#               ','): Counter({'and': 2, '<unk>': 4, 'all': 1, 'his': 1}),
#              ('and',
#               'the',
#               '<unk>'): Counter({'were': 1,
#                       '<unk>': 1,
#                       'that': 1,
#                       'of': 1,
#                       'is': 1,
#                       ',': 1}),
#              ('were', '<unk>', 'to'): Counter({'<unk>': 1}),
#              ('<unk>',
#               '<unk>',
#               'of'): Counter({'<unk>': 28,
#                       'its': 1,
#                       'time': 1,
#                       'the': 19,
#                       'people': 1,
#                       'my': 3,
#                       'their': 3,
#                       'a': 2,
#                       'around': 1}),
#              ('was', '<unk>', 'out'): Counter({'of': 3}),
#              ('<unk>',
#               'out',
#               'of'): Counter({'<unk>': 1, 'the': 4, 'its': 1, 'his': 1}),
#              ('out', 'of', '<unk>'): Counter({'for': 1}),
#              ('of', '<unk>', 'for'): Counter({'her': 1}),
#              ('<unk>', 'for', 'her'): Counter({'.': 1}),
#              ('for', 'her', '.'): Counter({'<unk>': 1}),
#              ('her', '.', '<unk>'): Counter({'all': 1}),
#              ('.', '<unk>', 'all'): Counter({'just': 1}),
#              ('<unk>', 'all', 'just'): Counter({'<unk>': 1}),
#              ('all', 'just', '<unk>'): Counter({'there': 1}),
#              ('just', '<unk>', 'there'): Counter({'<unk>': 1}),
#              ('<unk>', 'there', '<unk>'): Counter({'to': 1, '<unk>': 1}),
#              ('there', '<unk>', 'to'): Counter({'<unk>': 1}),
#              ('to', '<unk>', 'out'): Counter({'<unk>': 1, 'the': 1}),
#              ('<unk>',
#               'out',
#               '<unk>'): Counter({'<unk>': 1, 'and': 1, 'that': 1, 'to': 1}),
#              ('out', '<unk>', '<unk>'): Counter({'of': 1}),
#              ('of', '<unk>', 'our'): Counter({'<unk>': 1}),
#              ('<unk>', 'our', '<unk>'): Counter({'<unk>': 1}),
#              ('our', '<unk>', '<unk>'): Counter({'would': 1}),
#              ('<unk>', '<unk>', 'would'): Counter({'have': 1, 'be': 1}),
#              ('<unk>', 'would', 'have'): Counter({'that': 1}),
#              ('would', 'have', 'that'): Counter({'would': 1}),
#              ('have', 'that', 'would'): Counter({'<unk>': 1}),
#              ('that', 'would', '<unk>'): Counter({'<unk>': 1}),
#              ('would',
#               '<unk>',
#               '<unk>'): Counter({'a': 1, '<unk>': 1, 'into': 1}),
#              ('<unk>', '<unk>', 'a'): Counter({'<unk>': 13}),
#              ('<unk>', '.', 'Dad'): Counter({'<unk>': 1, 'was': 1}),
#              ('.', 'Dad', '<unk>'): Counter({'<unk>': 1}),
#              ('but',
#               '<unk>',
#               '<unk>'): Counter({'that': 1, 'is': 1, '.': 1, '<unk>': 1}),
#              ('that', '<unk>', 'had'): Counter({'<unk>': 1}),
#              ('<unk>', 'had', '<unk>'): Counter({'was': 1}),
#              ('had', '<unk>', 'was'): Counter({'<unk>': 1}),
#              ('out', 'of', 'the'): Counter({'<unk>': 4}),
#              ('<unk>', '<unk>', 'each'): Counter({'<unk>': 1}),
#              ('<unk>', 'each', '<unk>'): Counter({'that': 1}),
#              ('each', '<unk>', 'that'): Counter({'<unk>': 1}),
#              ('<unk>',
#               '<unk>',
#               'the'): Counter({'<unk>': 34,
#                       'door': 1,
#                       'ride': 2,
#                       'room': 1,
#                       'back': 1}),
#              ('the', '<unk>', 'being'): Counter({'a': 1}),
#              ('<unk>', 'being', 'a'): Counter({'<unk>': 1}),
# ...
#              ('He', 'was', 'a'): Counter({'<unk>': 1}),
#              (',', '<unk>', 'a'): Counter({'<unk>': 1}),
#              ('<unk>',
#               '.',
#               'It'): Counter({"'s": 1, '<unk>': 3, 'was': 2, 'would': 1}),
#              ('.', 'It', "'s"): Counter({'just': 1}),
#              ('It', "'s", 'just'): Counter({'like': 1}),
#              ("'s", 'just', 'like'): Counter({'them': 1}),
#              ('just', 'like', 'them'): Counter({'.': 1}),
#              ('like', 'them', '.'): Counter({'<unk>': 1}),
#              ('them', '.', '<unk>'): Counter({'<unk>': 1}),
#              ('<unk>', 'away', 'in'): Counter({'an': 1}),
#              ('away', 'in', 'an'): Counter({'<unk>': 1}),
#              ('in', 'an', '<unk>'): Counter({'<unk>': 2}),
#              ('an',
#               '<unk>',
#               '<unk>'): Counter({'.': 2,
#                       '<unk>': 4,
#                       'for': 1,
#                       'of': 1,
#                       'its': 1,
#                       ',': 1}),
#              ('``', '<unk>', 'is'): Counter({'the': 1}),
#              ('<unk>', 'is', 'the'): Counter({'<unk>': 3}),
#              ('is', 'the', '<unk>'): Counter({'for': 1, 'of': 1, 'room': 1}),
#              ('?', '<unk>', 'one'): Counter({'<unk>': 1}),
#              ('<unk>', 'one', '<unk>'): Counter({'a': 1, 'to': 1}),
#              ('one', '<unk>', 'a'): Counter({'<unk>': 1}),
#              ('<unk>',
#               '<unk>',
#               'are'): Counter({'there': 1, '<unk>': 4, 'being': 1}),
#              ('<unk>', 'are', 'there'): Counter({'in': 1}),
#              ('are', 'there', 'in'): Counter({'<unk>': 1}),
#              ('there', 'in', '<unk>'): Counter({'<unk>': 1}),
#              ('to', 'be', 'more'): Counter({'<unk>': 1}),
#              ('be', 'more', '<unk>'): Counter({'?': 1}),
#              ('more', '<unk>', '?'): Counter({'<unk>': 1}),
#              ('of', '<unk>', 'or'): Counter({'<unk>': 1}),
#              ('<unk>',
#               'are',
#               '<unk>'): Counter({'?': 1,
#                       'in': 2,
#                       'there': 1,
#                       '“': 1,
#                       'a': 1,
#                       'by': 1,
#                       'on': 1,
#                       'and': 1,
#                       '<unk>': 3}),
#              ('are', '<unk>', '?'): Counter({'<unk>': 1}),
#              ('?', '<unk>', 'the'): Counter({'<unk>': 1}),
#              ('<unk>', '<unk>', 'one'): Counter({'<unk>': 1, 'of': 1}),
#              ('one', '<unk>', 'to'): Counter({'have': 1}),
#              ('<unk>',
#               'to',
#               'have'): Counter({'a': 1, 'been': 1, 'the': 1, '<unk>': 2}),
#              ('to', 'have', 'a'): Counter({'<unk>': 1}),
#              ('have', 'a', '<unk>'): Counter({'<unk>': 2, 'to': 1, ',': 1}),
#              ('?', '<unk>', 'is'): Counter({'one': 1}),
#              ('<unk>', 'is', 'one'): Counter({'more': 1}),
#              ('is', 'one', 'more'): Counter({'<unk>': 1}),
#              ('one', 'more', '<unk>'): Counter({'that': 1}),
#              ('more', '<unk>', 'that'): Counter({'the': 1}),
#              ('<unk>', 'that', 'the'): Counter({'other': 1, '<unk>': 2}),
#              ('that', 'the', 'other'): Counter({'?': 1}),
#              ('the', 'other', '?'): Counter({'<unk>': 1}),
#              ('other', '?', '<unk>'): Counter({'<unk>': 1}),
#              ('a', '<unk>', 'for'): Counter({'the': 1}),
#              ('and', '<unk>', 'of'): Counter({'<unk>': 2, 'the': 1}),
#              ('<unk>',
#               '<unk>',
#               'out'): Counter({'this': 1,
#                       '<unk>': 2,
#                       'the': 1,
#                       'of': 1,
#                       'their': 1,
#                       'to': 1,
#                       'in': 1,
#                       'his': 1}),
#              ('<unk>', 'out', 'this'): Counter({'<unk>': 1}),
#              ('out', 'this', '<unk>'): Counter({'even': 1}),
#              ('this', '<unk>', 'even'): Counter({'<unk>': 1}),
#              ('<unk>',
#               'even',
#               '<unk>'): Counter({',': 1, 'that': 1, 'to': 1, 'at': 1}),
#              ('even', '<unk>', ','): Counter({'<unk>': 1}),
#              ('that', 'the', '<unk>'): Counter({'<unk>': 1, 'had': 1}),
#              ('<unk>',
#               '<unk>',
#               'you'): Counter({'to': 1, '<unk>': 3, 'would': 1, ',': 1}),
#              ('<unk>', 'you', 'to'): Counter({'<unk>': 1}),
#              ('you', 'to', '<unk>'): Counter({'down': 1}),
#              ('<unk>', 'down', 'to'): Counter({'the': 1}),
#              ('down', 'to', 'the'): Counter({'<unk>': 1}),
#              ('to', '<unk>', 'a'): Counter({'<unk>': 4}),
#              ('.', '<unk>', 'in'): Counter({'<unk>': 2, 'a': 1}),
#              ('<unk>',
#               'you',
#               '<unk>'): Counter({'<unk>': 2, '”': 1, ',': 1, 'the': 1}),
#              ('you',
#               '<unk>',
#               '<unk>'): Counter({'that': 1, '<unk>': 1, 'it': 1}),
#              ('the', '<unk>', 'had'): Counter({'the': 1}),
#              ('<unk>', 'had', 'the'): Counter({'<unk>': 1}),
#              ('had', 'the', '<unk>'): Counter({'<unk>': 1}),
#              ('of', '<unk>', 'about'): Counter({'him': 1}),
#              ('<unk>', 'about', 'him'): Counter({',': 1}),
#              ('about', 'him', ','): Counter({'a': 1}),
#              ('him', ',', 'a'): Counter({'<unk>': 1}),
#              ('a', '<unk>', 'that'): Counter({'<unk>': 2}),
#              ('that', '<unk>', 'be'): Counter({'<unk>': 1}),
#              ('<unk>', 'be', '<unk>'): Counter({'to': 1}),
#              ('be', '<unk>', 'to'): Counter({'<unk>': 1}),
#              ('.',
#               '<unk>',
#               ','): Counter({'<unk>': 5, 'I': 1, 'my': 1, 'the': 2, 'he': 1}),
#              (',', '<unk>', 'you'): Counter({'<unk>': 1}),
#              ('<unk>',
#               ',',
#               'you'): Counter({'<unk>': 1, 'had': 1, 'could': 1}),
#              (',', 'you', '<unk>'): Counter({'have': 1}),
#              ('you', '<unk>', 'have'): Counter({'been': 1}),
#              ('<unk>', 'have', 'been'): Counter({'<unk>': 1, 'the': 1}),
#              ('have',
#               'been',
#               '<unk>'): Counter({'to': 1, 'me': 1, 'in': 1, 'and': 1}),
#              ('been', '<unk>', 'to'): Counter({'<unk>': 1}),
#              ('to', '<unk>', 'the'): Counter({'<unk>': 14, 'over': 1}),
#              ('<unk>', "'s", 'face'): Counter({'to': 1, 'for': 1, '<unk>': 1}),
#              ("'s", 'face', 'to'): Counter({'a': 1}),
#              ('face', 'to', 'a'): Counter({'<unk>': 1}),
#              ('to', 'a', '<unk>'): Counter({'<unk>': 4, 'and': 2, 'by': 1}),
#              ('<unk>', 'who', 'could'): Counter({'<unk>': 1}),
#              ('who', 'could', '<unk>'): Counter({'a': 1}),
#              ('could', '<unk>', 'a'): Counter({'<unk>': 2}),
#              ('<unk>', ',', 'an'): Counter({'<unk>': 3}),
#              (',', 'an', '<unk>'): Counter({'or': 1, '<unk>': 1, 'about': 1}),
#              ('an', '<unk>', 'or'): Counter({'<unk>': 1}),
#              ('or', '<unk>', ','): Counter({'of': 1}),
#              ('<unk>', ',', 'of'): Counter({'<unk>': 1}),
#              (',', 'of', '<unk>'): Counter({'the': 1}),
#              ('of', '<unk>', 'the'): Counter({'<unk>': 2}),
#              ("'s", 'face', 'for'): Counter({'the': 1}),
#              ('face', 'for', 'the'): Counter({'<unk>': 1}),
#              ('of', '<unk>', 'you'): Counter({'would': 1}),
#              ('<unk>', 'you', 'would'): Counter({'<unk>': 1, 'be': 1}),
#              ('you', 'would', '<unk>'): Counter({'would': 1}),
#              ('would', '<unk>', 'would'): Counter({'<unk>': 1}),
#              ('<unk>', 'would', '<unk>'): Counter({'to': 1, '<unk>': 1}),
#              ('would', '<unk>', 'to'): Counter({'be': 1}),
#              ('to', 'be', 'of'): Counter({'a': 1}),
#              ('be', 'of', 'a'): Counter({'<unk>': 1}),
#              ('in', '<unk>', 'for'): Counter({'the': 1}),
#              ('to', '<unk>', 'an'): Counter({'<unk>': 1}),
#              ('<unk>', 'an', '<unk>'): Counter({'<unk>': 3, 'to': 1}),
#              ('you', 'would', 'be'): Counter({'<unk>': 1}),
#              ('would', 'be', '<unk>'): Counter({'in': 2, 'by': 1, '<unk>': 1}),
#              ('be', '<unk>', 'in'): Counter({'<unk>': 1, 'the': 1}),
#              ('in', '<unk>', 'a'): Counter({'<unk>': 2}),
#              (',', '<unk>', 'at'): Counter({'the': 2}),
#              (',', 'you', 'had'): Counter({'<unk>': 1}),
#              ('you', 'had', '<unk>'): Counter({'a': 1}),
#              ('had', '<unk>', 'a'): Counter({'more': 1}),
#              ('<unk>', 'a', 'more'): Counter({'<unk>': 1}),
#              ('a', 'more', '<unk>'): Counter({'<unk>': 1}),
#              ('more', '<unk>', '<unk>'): Counter({'or': 1}),
#              ('<unk>', '<unk>', 'or'): Counter({',': 1, '<unk>': 5, 'a': 1}),
#              ('<unk>', 'or', ','): Counter({'by': 1}),
#              ('or', ',', 'by'): Counter({'<unk>': 1}),
#              (',', 'by', '<unk>'): Counter({',': 1}),
#              ('by', '<unk>', ','): Counter({'a': 1, '<unk>': 1}),
#              ('<unk>', 'to', 'this'): Counter({'<unk>': 2}),
#              ('to', 'this', '<unk>'): Counter({'<unk>': 1, 'of': 1}),
#              ('<unk>', 'would', 'be'): Counter({'the': 1, '<unk>': 1}),
#              ('would', 'be', 'the'): Counter({'<unk>': 1}),
#              ('<unk>',
#               '<unk>',
#               'by'): Counter({'the': 2,
#                       '<unk>': 6,
#                       'an': 1,
#                       'a': 2,
#                       'are': 1}),
#              ('by',
#               'the',
#               '<unk>'): Counter({'.': 1, 'of': 1, '<unk>': 3, 'that': 1}),
#              ('in', '<unk>', 'even'): Counter({'<unk>': 1}),
#              ('even', '<unk>', 'that'): Counter({'<unk>': 1}),
#              ('that', '<unk>', 'of'): Counter({'the': 1}),
#              ("'s", 'face', '<unk>'): Counter({'like': 1}),
#              ('face', '<unk>', 'like'): Counter({',': 1}),
#              ('<unk>', 'like', ','): Counter({'but': 1}),
#              ('like', ',', 'but'): Counter({'<unk>': 1}),
#              ('<unk>', '<unk>', 'is'): Counter({'the': 1, '<unk>': 7}),
#              ('<unk>', 'and', 'not'): Counter({'to': 1, 'a': 1}),
#              ('and', 'not', 'to'): Counter({'be': 1}),
#              ('not', 'to', 'be'): Counter({'<unk>': 1}),
#              ('be', '<unk>', '<unk>'): Counter({'<unk>': 1, ',': 1, 'and': 1}),
#              ('<unk>', 'the', 'door'): Counter({'<unk>': 1}),
#              ('door', '<unk>', '.'): Counter({'The': 1}),
#              (',', 'with', 'a'): Counter({'<unk>': 1}),
#              ('a', '<unk>', 'but'): Counter({'<unk>': 1}),
#              ('<unk>', 'but', '<unk>'): Counter({'<unk>': 1}),
#              ('A', '<unk>', 'of'): Counter({'<unk>': 1, 'a': 1}),
#              ('<unk>',
#               'with',
#               '<unk>'): Counter({'<unk>': 5,
#                       ',': 2,
#                       'their': 1,
#                       '.': 1,
#                       'children': 1}),
#              ('<unk>',
#               '<unk>',
#               'over'): Counter({'me': 1, 'the': 1, 'who': 1}),
#              ('<unk>', 'over', 'me'): Counter({'.': 1}),
#              ('over', 'me', '.'): Counter({'<unk>': 1}),
#              ('me', '.', '<unk>'): Counter({'are': 1, 'I': 1}),
#              ('.', '<unk>', 'are'): Counter({'<unk>': 2}),
#              ('are', '<unk>', 'in'): Counter({'the': 1, '<unk>': 1}),
#              ('<unk>', 'room', 'of'): Counter({'the': 1}),
#              ('room', 'of', 'the'): Counter({'<unk>': 1}),
#              ('<unk>',
#               '<unk>',
#               'on'): Counter({'the': 3,
#                       'one': 1,
#                       '<unk>': 1,
#                       'to': 1,
#                       'an': 1,
#                       'a': 3,
#                       'her': 1}),
#              ('out', '<unk>', 'and'): Counter({'<unk>': 1}),
#              ('.', 'A', 'little'): Counter({'<unk>': 1}),
#              ('A', 'little', '<unk>'): Counter({'<unk>': 1}),
#              ('<unk>', 'from', 'where'): Counter({'I': 1}),
#              ('from', 'where', 'I'): Counter({'<unk>': 1}),
#              ('where', 'I', '<unk>'): Counter({'is': 1, '<unk>': 2}),
#              ('I', '<unk>', 'is'): Counter({'a': 1}),
#              ('<unk>', 'is', 'a'): Counter({'<unk>': 2}),
#              ('is', 'a', '<unk>'): Counter({'.': 1, '<unk>': 1, 'of': 1}),
#              ('A', '<unk>', '<unk>'): Counter({'<unk>': 3}),
#              ('<unk>', '<unk>', 'there'): Counter({'.': 1, '<unk>': 1}),
#              ('<unk>', 'there', '.'): Counter({'<unk>': 2}),
#              ('to', 'have', 'been'): Counter({'<unk>': 1}),
#              ('been', '<unk>', 'me'): Counter({'<unk>': 1}),
#              ('<unk>', 'me', '<unk>'): Counter({',': 1, 'back': 1, 'that': 1}),
#              ('me', '<unk>', ','): Counter({'as': 1}),
#              ('<unk>', ',', 'as'): Counter({'she': 2, 'the': 1, 'he': 1}),
#              (',', 'as', 'she'): Counter({'<unk>': 2}),
#              ('as',
#               'she',
#               '<unk>'): Counter({'to': 1, 'at': 1, '<unk>': 1, 'down': 1}),
#              ('she', '<unk>', 'to'): Counter({'the': 1}),
#              ('are', '<unk>', 'there'): Counter({'.': 1}),
#              ('to', '<unk>', 'their'): Counter({'<unk>': 3}),
#              ('<unk>',
#               'their',
#               '<unk>'): Counter({'from': 2,
#                       'of': 1,
#                       '<unk>': 3,
#                       'to': 2,
#                       '.': 2,
#                       'into': 1}),
#              ('their', '<unk>', 'from'): Counter({'the': 1, '<unk>': 1}),
#              ('<unk>', ',', 'where'): Counter({'an': 1}),
#              (',', 'where', 'an'): Counter({'<unk>': 1}),
#              ('where', 'an', '<unk>'): Counter({'<unk>': 1}),
#              ('<unk>',
#               'is',
#               '<unk>'): Counter({'from': 1,
#                       'through': 1,
#                       '<unk>': 8,
#                       'in': 2,
#                       'on': 1,
#                       'by': 1,
#                       'and': 1,
#                       '.': 1,
#                       'to': 1,
#                       'out': 1,
#                       'as': 1}),
#              ('is', '<unk>', 'from'): Counter({'.': 1}),
#              ('<unk>', 'from', '.'): Counter({'<unk>': 1}),
#              ('from', '.', '<unk>'): Counter({',': 1}),
#              ('or', '<unk>', '.'): Counter({'<unk>': 2}),
#              ('.', '<unk>', 'by'): Counter({'one': 1}),
#              ('<unk>', 'by', 'one'): Counter({',': 1}),
#              ('by', 'one', ','): Counter({'the': 1}),
#              ('one', ',', 'the'): Counter({'<unk>': 1}),
#              ('out', 'the', '<unk>'): Counter({'<unk>': 2, 'at': 1}),
#              ('<unk>', '<unk>', '“'): Counter({'<unk>': 2}),
#              ('“', '<unk>', ','): Counter({'<unk>': 3}),
#              ('<unk>', '”', 'or'): Counter({',': 1}),
#              ('”', 'or', ','): Counter({'“': 1}),
#              ('or', ',', '“'): Counter({'<unk>': 1}),
#              ('”', '<unk>', 'on'): Counter({'the': 1}),
#              ('the', '<unk>', 'are'): Counter({'<unk>': 2}),
#              ('are', '<unk>', '“'): Counter({'<unk>': 1}),
#              ('”', '<unk>', '.'): Counter({'<unk>': 1}),
#              ('The', '<unk>', 'are'): Counter({'<unk>': 1}),
#              ('are', '<unk>', 'a'): Counter({'<unk>': 1}),
#              ('<unk>', 'of', 'people'): Counter({'with': 1}),
#              ('of', 'people', 'with'): Counter({'<unk>': 1}),
#              ('people', 'with', '<unk>'): Counter({'<unk>': 1}),
#              ('<unk>',
#               '<unk>',
#               'down'): Counter({'at': 1,
#                       'the': 1,
#                       'their': 1,
#                       'on': 1,
#                       'as': 1}),
#              ('<unk>', 'down', 'at'): Counter({'me': 1}),
#              ('down', 'at', 'me'): Counter({',': 1}),
#              ('at', 'me', ','): Counter({'from': 1}),
#              ('me', ',', 'from'): Counter({'<unk>': 1}),
#              (',', 'from', '<unk>'): Counter({'<unk>': 1}),
#              ('from', '<unk>', '<unk>'): Counter({'over': 1, '<unk>': 1}),
#              ...})

# %%
a = (3)
list(a[1:])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-4e23074d12ad> in <cell line: 2>()
#       1 a = (3)
# ----> 2 list(a[1:])
#
# TypeError: 'int' object is not subscriptable
